# %% [markdown]
# # Python Packages: Importing, Using, and Managing Tools
#
# ## Learning goals
#
# By the end of this notebook, you should be able to:
#
# 1. Explain what a Python package is and why packages are useful for data analysis.
# 2. Import packages using common import patterns.
# 3. Use functions, classes, and methods from imported packages.
# 4. Distinguish between Python's standard library and third-party packages.
# 5. Explain, at a basic level, how Conda environments help manage Python packages.
# 6. Check which Python interpreter or kernel your notebook is using.
#
# This lesson focuses on the practical basics. You do **not** need to understand the full Python package ecosystem yet.

# %% [markdown]
# ## 1. Why packages matter
#
# Python gives us the core language: variables, lists, dictionaries, loops, functions, and other building blocks. Packages extend Python by adding specialized tools.
#
# For environmental data analysis, we often use packages for:
#
# - reading and organizing tabular data,
# - working with file paths,
# - calculating summary statistics,
# - creating plots,
# - analyzing spatial or time-series data.
#
# Instead of writing everything from scratch, we import packages written and tested by others.

# %% [markdown]
# ## 2. Common import patterns
#
# You will see three common import patterns in this course.
#
# | Pattern | Example | What it means |
# |---|---|---|
# | Import the whole package | `import math` | Use the package name before its tools, such as `math.sqrt()` |
# | Import with an alias | `import pandas as pd` | Use a shorter conventional nickname, such as `pd.DataFrame()` |
# | Import one tool from a package | `from pathlib import Path` | Use that tool directly, such as `Path("data")` |
#
# Aliases are common when a package is used frequently. For example, `pandas` is almost always imported as `pd`.

# %%
import math

math.sqrt(25)
# Out:
# 5.0

# %%
import pandas as pd

pd.DataFrame({
    "site": ["A", "B", "C"],
    "temperature_c": [18.2, 21.5, 19.8]
})
# Out:
#   site  temperature_c
# 0    A           18.2
# 1    B           21.5
# 2    C           19.8

# %%
from pathlib import Path

project_folder = Path(".")
project_folder
# Out:
# WindowsPath('.')

# %% [markdown]
# ## 3. Using tools from packages
#
# After a package is imported, you can use the functions, objects, and methods it provides.
#
# A useful pattern is:
#
# ```python
# package_name.tool_name()
# ```
#
# For example, after running `import math`, the square root function is available as `math.sqrt()`.

# %%
import math

value = 49
root = math.sqrt(value)

root
# Out:
# 7.0

# %% [markdown]
# ### A small pandas example
#
# `pandas` is a third-party package for working with tabular data. A `DataFrame` is the main pandas object for storing rows and columns.

# %%
import pandas as pd

data = pd.DataFrame({
    "lake": ["Mendota", "Monona", "Wingra"],
    "depth_m": [25.3, 22.5, 4.3],
    "surface_area_km2": [39.4, 13.2, 1.4]
})

data
# Out:
#       lake  depth_m  surface_area_km2
# 0  Mendota     25.3              39.4
# 1   Monona     22.5              13.2
# 2   Wingra      4.3               1.4

# %%
data["depth_m"].mean()
# Out:
# np.float64(17.366666666666664)

# %% [markdown]
# ## 4. Standard library vs. third-party packages
#
# Some packages are included automatically when Python is installed. These are part of Python's **standard library**.
#
# Other packages are created outside of core Python and must be installed separately. These are called **third-party packages**.
#
# | Standard library examples | Third-party examples |
# |---|---|
# | `math` | `pandas` |
# | `pathlib` | `numpy` |
# | `datetime` | `matplotlib` |
# | `statistics` | `geopandas` |
#
# In this course, many of our most important tools will be third-party packages.

# %% [markdown]
# ## 5. Conda environments: the basic idea
#
# Our course uses **Miniforge** and **Conda** to manage Python and its packages.
#
# A Conda environment is a self-contained collection of:
#
# - a Python version,
# - installed packages,
# - package versions that are designed to work together.
#
# This matters because data analysis projects often depend on several packages at once. Environments help keep those tools organized and reproducible.
#
# For now, the key point is simple: when you work in VS Code or Jupyter, make sure you are using the correct course environment/kernel.

# %% [markdown]
# ### Installing packages
#
# You will usually install packages from the terminal, not from inside the notebook.
#
# Common Conda command:
#
# ```bash
# conda install package-name
# ```
#
# Example:
#
# ```bash
# conda install pandas
# ```
#
# Sometimes you may see `pip install package-name`. `pip` is another Python package installer. In this course, prefer Conda unless instructed otherwise.

# %% [markdown]
# ## 6. Which Python am I using?
#
# A common beginner problem is that VS Code or Jupyter may be using a different Python environment than the one you expected.
#
# This command shows the Python executable connected to the active notebook kernel.

# %%
import sys

sys.executable
# Out:
# 'c:\\Users\\sjh104\\.conda\\envs\\env700\\python.exe'

# %% [markdown]
# If this path does not look like your course environment, you may need to change the selected notebook kernel in VS Code.

# %% [markdown]
# ## 7. Mini workflow: packages working together
#
# In real analyses, packages are often used together. Here we use pandas to create a small dataset and pandas' built-in plotting method to make a quick exploratory plot.

# %%
import pandas as pd

rainfall = pd.DataFrame({
    "year": [2021, 2022, 2023, 2024],
    "rainfall_mm": [940, 1015, 875, 960]
})

rainfall
# Out:
#    year  rainfall_mm
# 0  2021          940
# 1  2022         1015
# 2  2023          875
# 3  2024          960

# %%
rainfall.plot(x="year", y="rainfall_mm", kind="line")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# The point is not the plot itself. The point is that packages give us reusable tools for common data tasks.

# %% [markdown]
# ## 8. Practice exercises
#
# Complete the exercises below in the code cells provided.

# %% [markdown]
# ### Exercise 1: Import packages
#
# Import the following:
#
# - `math`
# - `pandas` using the alias `pd`
# - `Path` from `pathlib`

# %%
# Write your imports here
import math
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Exercise 2: Use imported tools
#
# Use the packages you imported to do the following:
#
# 1. Calculate the square root of `144`.
# 2. Create a `Path` object pointing to a folder named `data`.
# 3. Create a small pandas `DataFrame` with at least two columns.

# %%
# 1. Calculate the square root of 144
math.sqrt(144)
# Out:
# 12.0

# %%
# 2. Create a Path object for a folder named data
#get current working directory 
Path.cwd()

#create path object for a folder named data
data_folder = Path("c:/Users/sjh104/EDE 700/ENV700/Data")
print(data_folder)

#get home directory
#Path.home()

#read contents of a file
#.read_text()

#write text to a file
#.write_text()
# Out:
# c:\Users\sjh104\EDE 700\ENV700\Data

# %%
# 3. Create a small pandas DataFrame
electricity_generation = pd.DataFrame({
    "year": [2020,2021,2022,2023],
    "generation_kWh": [172,100,88, 99]
})

electricity_generation
# Out:
#    year  generation_kWh
# 0  2020             172
# 1  2021             100
# 2  2022              88
# 3  2023              99

# %% [markdown]
# ### Exercise 3: Check your active Python interpreter
#
# Run the code below. Then add a short Markdown note explaining what the output tells you.

# %%
import sys

sys.executable
# Out:
# 'c:\\Users\\sjh104\\.conda\\envs\\env700\\python.exe'

# %% [markdown]
# Write your explanation here:
#
# >This tells you what kernel is activated, meaning what conda environment is being used. This is important for packages and version of Python.

# %% [markdown]
# ## Key takeaways
#
# - Packages extend Python with specialized tools.
# - Packages must be imported before you can use them.
# - `import pandas as pd` is an alias pattern used throughout data analysis.
# - Some packages come with Python; others must be installed separately.
# - Conda environments help keep Python and packages organized.
# - In VS Code/Jupyter, the selected kernel determines which Python environment your notebook is using.
